# %%
import pandas as pd 
import os

# %%
parent_dir = os.path.abspath("/Users/revekkagershovich/Dropbox (MIT)/StateLaws")
os.chdir(parent_dir)
assert os.path.exists(parent_dir), "parent_dir does not exist"
data_dir = "./2_data/2_intermediate"
assert os.path.exists(data_dir), "Data directory does not exist"

# %%
census_econ = pd.read_csv(os.path.join(data_dir, "./employment_data/detailed_employment_data.csv"))

# %%
census_econ.sample(5, random_state=44)
# Out:
#            STATE  YEAR  agricultural_laborers  agricultural_pursuits  \
# 457  Connecticut  1970                    NaN                    NaN
# 78      Nebraska  1990                    NaN                    NaN
# 350      Wyoming  1930                    NaN               0.079731
# 474    Minnesota  1970                    NaN                    NaN
# 398    Wisconsin  1940                    NaN                    NaN
#
#      agriculture  agriculture_forestry_animal_husb  boot_shoe_makers  \
# 457          NaN                               NaN               NaN
# 78           NaN                          0.074872               NaN
# 350     0.333106                               NaN               NaN
# 474          NaN                               NaN               NaN
# 398          NaN                          0.259403               NaN
#
#      building_grounds_maintenance  business_repair_services  clergymen  ...  \
# ...

# %%
census_econ["STATE"].nunique()
# Out:
# 55

# %%
# Create a DataFrame with the list of all states
all_states = pd.DataFrame({'STATE': [
    'Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado',
    'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
    'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
    'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
    'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
    'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
    'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
    'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
    'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
    'West Virginia', 'Wisconsin', 'Wyoming'
]})

# Perform a full outer merge
merged_states = all_states.merge(census_econ[['STATE']], on='STATE', how='outer', indicator=True)

# Check states absent in census_econ
absent_states = merged_states[merged_states['_merge'] == 'left_only']['STATE']
print("States absent in census_econ:")
print(absent_states)

# Check states that are not supposed to be there but are present in census_econ
extra_states = merged_states[merged_states['_merge'] == 'right_only']['STATE']
print("\nStates not supposed to be there but present in census_econ:")
print(extra_states)
# Out:
# States absent in census_econ:
# Series([], Name: STATE, dtype: object)
#
# States not supposed to be there but present in census_econ:
# 66                      Dakota
# 77        District Of Columbia
# 78        District Of Columbia
# 79        District Of Columbia
# 80        District Of Columbia
# 81        District Of Columbia
# 82        District Of Columbia
# 83        District Of Columbia
# 84        District Of Columbia
# 85        District Of Columbia
# 86        District Of Columbia
# 133                     Indian
# 284                        New
# 285                        New
# 382    Persons in the Military
# Name: STATE, dtype: object

# %%
census_econ = pd.read_csv(os.path.join(data_dir, "./employment_data/detailed_employment_data.csv"))

# Define the list of unwanted states
unwanted_states = [
    'Dakota', 'District Of Columbia', 'Indian', 'New', 'Persons in the Military'
]

weird_states = [
    'Dakota', 'Indian', 'New', 'Persons in the Military'
]

census_econ_weird = census_econ[census_econ['STATE'].isin(weird_states)]

print(census_econ_weird.shape)
# Out:
# (5, 61)

# %%
census_econ_weird['YEAR'].value_counts()
# Out:
# YEAR
# 1900    3
# 1880    2
# Name: count, dtype: int64

# %%
# Filter out the unwanted states
census_econ_clean = census_econ[~census_econ['STATE'].isin(unwanted_states)]

# %%
census_econ_1880 = census_econ_clean[census_econ_clean['YEAR'] == 1880]

# List of states that existed by 1880
states_1880 = pd.DataFrame({'STATE': [
    'Alabama', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware',
    'Florida', 'Georgia', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky',
    'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
    'Mississippi', 'Missouri', 'Nebraska', 'Nevada', 'New Hampshire',
    'New Jersey', 'New York', 'North Carolina', 'Ohio', 'Oregon',
    'Pennsylvania', 'Rhode Island', 'South Carolina', 'Tennessee', 'Texas',
    'Vermont', 'Virginia', 'West Virginia', 'Wisconsin'
]})

# Filter census data for the year 1880
census_econ_1880 = census_econ[census_econ['YEAR'] == 1880]

# Perform a full outer merge
merged_states = states_1880.merge(census_econ_1880[['STATE']], on='STATE', how='outer', indicator=True)

# Check states absent in census_econ_1880
absent_states = merged_states[merged_states['_merge'] == 'left_only']['STATE']
print("States absent in census_econ_1880:")
print(absent_states)

# Check states not supposed to be there but present in census_econ_1880
extra_states_1880 = merged_states[merged_states['_merge'] == 'right_only']['STATE']
print("\nStates not supposed to be there but present in census_econ_1880:")
print(extra_states_1880)
# Out:
# States absent in census_econ_1880:
# Series([], Name: STATE, dtype: object)
#
# States not supposed to be there but present in census_econ_1880:
# 1                  Arizona
# 6                   Dakota
# 8     District Of Columbia
# 11                   Idaho
# 25                 Montana
# 28                     New
# 40                    Utah
# 43              Washington
# 46                 Wyoming
# Name: STATE, dtype: object

# %%
# List of states that existed by 1900
states_1900 = pd.DataFrame({'STATE': [
    'Alabama', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware',
    'Florida', 'Georgia', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
    'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan',
    'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
    'New Hampshire', 'New Jersey', 'New York', 'North Carolina', 'North Dakota',
    'Ohio', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
    'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
    'West Virginia', 'Wisconsin', 'Wyoming'
]})

# Filter census data for the year 1900
census_econ_1900 = census_econ[census_econ['YEAR'] == 1900]

# Perform a full outer merge
merged_states_1900 = states_1900.merge(census_econ_1900[['STATE']], on='STATE', how='outer', indicator=True)

# Check states absent in census_econ_1900
absent_states_1900 = merged_states_1900[merged_states_1900['_merge'] == 'left_only']['STATE']
print("States absent in census_econ_1900:")
print(absent_states_1900)

# Check states not supposed to be there but present in census_econ_1900
extra_states_1900 = merged_states_1900[merged_states_1900['_merge'] == 'right_only']['STATE']
print("\nStates not supposed to be there but present in census_econ_1900:")
print(extra_states_1900)
# Out:
# States absent in census_econ_1900:
# Series([], Name: STATE, dtype: object)
#
# States not supposed to be there but present in census_econ_1900:
# 1                      Alaska
# 2                     Arizona
# 8        District Of Columbia
# 11                     Hawaii
# 14                     Indian
# 30                        New
# 37                   Oklahoma
# 40    Persons in the Military
# Name: STATE, dtype: object

# %%
census_econ_1880_extra = census_econ_1880[census_econ_1880['STATE'].isin(extra_states)]

# %%
census_econ_1880_extra
# Out:
#                     STATE  YEAR  agricultural_laborers  agricultural_pursuits  \
# 159                Dakota  1880               0.050761                    NaN
# 161  District Of Columbia  1880               0.003751                    NaN
# 183                   New  1880               0.052366                    NaN
#
#      agriculture  agriculture_forestry_animal_husb  boot_shoe_makers  \
# 159          NaN                               NaN          0.001588
# 161          NaN                               NaN          0.005599
# 183          NaN                               NaN          0.001711
#
#      building_grounds_maintenance  business_repair_services  clergymen  ...  \
# 159                           NaN                       NaN   0.001722  ...
# 161                           NaN                       NaN   0.002287  ...
# 183                           NaN                       NaN   0.001058  ...
#
#      service_workers  stockraisers_herders  surgeons_physicians  \
# ...

# %%
census_econ['YEAR'].value_counts()
# Out:
# YEAR
# 1900    53
# 1980    51
# 1990    51
# 2000    51
# 1950    51
# 1970    51
# 1920    49
# 1930    49
# 1940    49
# 1880    47
# Name: count, dtype: int64

# %%
census_dakota = census_econ[
    ((census_econ['STATE'] == 'North Dakota') | (census_econ['STATE'] == 'South Dakota'))
]

# Created in 1889

census_dakota['YEAR'].value_counts()
# Out:
# YEAR
# 1980    2
# 1990    2
# 2000    2
# 1900    2
# 1920    2
# 1930    2
# 1940    2
# 1950    2
# 1970    2
# Name: count, dtype: int64

# %%
census_econ_weird.head()
# Out:
#                        STATE  YEAR  agricultural_laborers  \
# 159                   Dakota  1880               0.050761
# 183                      New  1880               0.052366
# 214                   Indian  1900                    NaN
# 232                      New  1900                    NaN
# 240  Persons in the Military  1900                    NaN
#
#      agricultural_pursuits  agriculture  agriculture_forestry_animal_husb  \
# 159                    NaN          NaN                               NaN
# 183                    NaN          NaN                               NaN
# 214               0.691182          NaN                               NaN
# 232               0.412208          NaN                               NaN
# 240               0.000343          NaN                               NaN
#
#      boot_shoe_makers  building_grounds_maintenance  business_repair_services  \
# 159          0.001588                           NaN                       NaN
# ...

# %%
census_econ["STATE"].nunique()
# Out:
# 55

# %%
census_econ["STATE"].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District Of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming', 'Dakota', 'New', 'Indian',
#        'Persons in the Military'], dtype=object)

# %%
# Filter out extra states for 1880
census_econ_clean = census_econ_clean[
    ~((census_econ_clean['YEAR'] == 1880) & (census_econ_clean['STATE'].isin(extra_states_1880)))
]

# Filter out extra states for 1900
census_econ_clean = census_econ_clean[
    ~((census_econ_clean['YEAR'] == 1900) & (census_econ_clean['STATE'].isin(extra_states_1900)))
]

# print(census_econ_clean['STATE'].value_counts().reset_index())

print(census_econ_clean['YEAR'].value_counts().reset_index())
# Out:
#    YEAR  count
# 0  1980     50
# 1  1990     50
# 2  2000     50
# 3  1950     50
# 4  1970     50
# 5  1920     48
# 6  1930     48
# 7  1940     48
# 8  1900     45
# 9  1880     38

# %%
census_econ_clean.to_csv(os.path.join(data_dir, "./employment_data/detailed_employment_data_cleanish.csv"), index=False)
